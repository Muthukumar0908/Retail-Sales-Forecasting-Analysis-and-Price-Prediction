# %%
import pandas as pd
import numpy as np

from datetime import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\ADMIN\Videos\capstion_project\final_project\clean_dataset.csv")
df
# Out:
#         Store        Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0           1  2010-05-02        42.31       2.572  211.096358         8.106
# 1           1  2010-05-02        42.31       2.572  211.096358         8.106
# 2           1  2010-05-02        42.31       2.572  211.096358         8.106
# 3           1  2010-05-02        42.31       2.572  211.096358         8.106
# 4           1  2010-05-02        42.31       2.572  211.096358         8.106
# ...       ...         ...          ...         ...         ...           ...
# 421565     45  2012-10-26        58.85       3.882  192.308899         8.667
# 421566     45  2012-10-26        58.85       3.882  192.308899         8.667
# 421567     45  2012-10-26        58.85       3.882  192.308899         8.667
# 421568     45  2012-10-26        58.85       3.882  192.308899         8.667
# 421569     45  2012-10-26        58.85       3.882  192.308899         8.667
#
# ...

# %%
df1=pd.read_csv(r"C:\Users\ADMIN\Videos\capstion_project\final_project\data_analysis.csv")
df1
# Out:
#         Store        Date  Temperature_fahr  Fuel_Price         CPI  \
# 0           1  2011-11-11             59.11       3.297  217.998085
# 1           1  2011-11-11             59.11       3.297  217.998085
# 2           1  2011-11-11             59.11       3.297  217.998085
# 3           1  2011-11-11             59.11       3.297  217.998085
# 4           1  2011-11-11             59.11       3.297  217.998085
# ...       ...         ...               ...         ...         ...
# 421565     45  2011-04-11             43.92       3.551  187.970363
# 421566     45  2011-04-11             43.92       3.551  187.970363
# 421567     45  2011-04-11             43.92       3.551  187.970363
# 421568     45  2011-04-11             43.92       3.551  187.970363
# 421569     45  2011-04-11             43.92       3.551  187.970363
#
#         Unemployment  IsHoliday  Dept  Weekly_Sales Type    Size   MarkDown  \
# ...

# %% [markdown]
# ## Remove the outlier

# %%
plt.figure(figsize=(16,6))
sns.boxplot(data=df1)
plt.show()

# %%
for i in df1.columns:
    if df1[i].dtype != 'object':
        print(i)
        plt.figure(figsize=(16,6))
        sns.boxplot(data=df1[i])
        plt.show()
# Out:
# Store
# Temperature_fahr
# Fuel_Price
# CPI
# Unemployment
# IsHoliday
# Dept
# Weekly_Sales
# Size
# MarkDown
# day
# month
# year
# weekly_sales_date
# week_of_number

# %% [markdown]
# # markdown calculate

# %%
q1=df1['MarkDown'].quantile(0.25)
q3=df1['MarkDown'].quantile(0.75)
iqr=q3-q1

# %%
q1,q3,iqr
# Out:
# (7994.093999999999, 23694.14, 15700.046)

# %%
upper_limit=q3+(1.5*iqr)
lower_limit=q1-(1.5*iqr)

# %%
upper_limit,lower_limit
# Out:
# (47244.209, -15555.975)

# %%
df1[(df1['MarkDown']>upper_limit) | (df1['MarkDown']<lower_limit)]
# Out:
#         Store        Date  Temperature_fahr  Fuel_Price         CPI  \
# 144         1  2011-11-25             60.14       3.236  218.467621
# 145         1  2011-11-25             60.14       3.236  218.467621
# 146         1  2011-11-25             60.14       3.236  218.467621
# 147         1  2011-11-25             60.14       3.236  218.467621
# 148         1  2011-11-25             60.14       3.236  218.467621
# ...       ...         ...               ...         ...         ...
# 421558     45  2011-04-11             43.92       3.551  187.970363
# 421563     45  2011-04-11             43.92       3.551  187.970363
# 421564     45  2011-04-11             43.92       3.551  187.970363
# 421565     45  2011-04-11             43.92       3.551  187.970363
# 421566     45  2011-04-11             43.92       3.551  187.970363
#
#         Unemployment  IsHoliday  Dept  Weekly_Sales Type    Size   MarkDown  \
# ...

# %%
df1['IsHoliday'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# # unemployee

# %%
q1=df1['Unemployment'].quantile(0.25)
q3=df1['Unemployment'].quantile(0.75)
iqr=q3-q1

# %%
upper_limit=q3+(1.5*iqr)
lower_limit=q1-(1.5*iqr)

# %%
upper_limit,lower_limit
# Out:
# (11.093499999999999, 4.369500000000001)

# %%
df1[(df1['MarkDown']>upper_limit) | (df1['MarkDown']<lower_limit)]
# Out:
#         Store        Date  Temperature_fahr  Fuel_Price         CPI  \
# 0           1  2011-11-11             59.11       3.297  217.998085
# 1           1  2011-11-11             59.11       3.297  217.998085
# 2           1  2011-11-11             59.11       3.297  217.998085
# 3           1  2011-11-11             59.11       3.297  217.998085
# 4           1  2011-11-11             59.11       3.297  217.998085
# ...       ...         ...               ...         ...         ...
# 421565     45  2011-04-11             43.92       3.551  187.970363
# 421566     45  2011-04-11             43.92       3.551  187.970363
# 421567     45  2011-04-11             43.92       3.551  187.970363
# 421568     45  2011-04-11             43.92       3.551  187.970363
# 421569     45  2011-04-11             43.92       3.551  187.970363
#
#         Unemployment  IsHoliday  Dept  Weekly_Sales Type    Size   MarkDown  \
# ...

# %%
df1.head()
# Out:
#    Store        Date  Temperature_fahr  Fuel_Price         CPI  Unemployment  \
# 0      1  2011-11-11             59.11       3.297  217.998085         7.866
# 1      1  2011-11-11             59.11       3.297  217.998085         7.866
# 2      1  2011-11-11             59.11       3.297  217.998085         7.866
# 3      1  2011-11-11             59.11       3.297  217.998085         7.866
# 4      1  2011-11-11             59.11       3.297  217.998085         7.866
#
#    IsHoliday  Dept  Weekly_Sales Type    Size  MarkDown  day  month  year  \
# 0      False     1      18689.54    A  151315  25671.68   11     11  2011
# 1      False     2      44936.47    A  151315  25671.68   11     11  2011
# 2      False     3       9959.64    A  151315  25671.68   11     11  2011
# 3      False     4      36826.52    A  151315  25671.68   11     11  2011
# 4      False     5      31002.65    A  151315  25671.68   11     11  2011
#
#      Month  weekly_sales_date  week_of_number
# ...

# %%
df1['Date']=pd.to_datetime(df1['Date'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Store              421570 non-null  int64
#  1   Date               421570 non-null  datetime64[ns]
#  2   Temperature_fahr   421570 non-null  float64
#  3   Fuel_Price         421570 non-null  float64
#  4   CPI                421570 non-null  float64
#  5   Unemployment       421570 non-null  float64
#  6   IsHoliday          421570 non-null  bool
#  7   Dept               421570 non-null  int64
#  8   Weekly_Sales       421570 non-null  float64
#  9   Type               421570 non-null  object
#  10  Size               421570 non-null  int64
#  11  MarkDown           421570 non-null  float64
#  12  day                421570 non-null  int64
#  13  month              421570 non-null  int64
#  14  year               421570 non-null  int64
# ...

# %% [markdown]
# # Odinial encoding

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()
for i in df1.columns:
    if df1[i].dtype == 'object':
#         col_name = i
        df1[i] = enc.fit_transform(df1[[i]])
        encoding = df1[i].sort_values().unique()
        globals()[i] = {}
        decoded_data = enc.inverse_transform(df1[[i]])
        decoded = sorted(np.unique(decoded_data)) 
        globals()[i] = dict(zip(decoded, encoding))

# %%
for i in df1.columns:
    if df1[i].dtype == 'bool':
#         col_name = i
        df1[i] = enc.fit_transform(df1[[i]])
        encoding = df1[i].sort_values().unique()
        globals()[i] = {}
        decoded_data = enc.inverse_transform(df1[[i]])
        decoded = sorted(np.unique(decoded_data)) 
        globals()[i] = dict(zip(decoded, encoding))

# %%
df1
# Out:
#         Store       Date  Temperature_fahr  Fuel_Price         CPI  \
# 0           1 2011-11-11             59.11       3.297  217.998085
# 1           1 2011-11-11             59.11       3.297  217.998085
# 2           1 2011-11-11             59.11       3.297  217.998085
# 3           1 2011-11-11             59.11       3.297  217.998085
# 4           1 2011-11-11             59.11       3.297  217.998085
# ...       ...        ...               ...         ...         ...
# 421565     45 2011-04-11             43.92       3.551  187.970363
# 421566     45 2011-04-11             43.92       3.551  187.970363
# 421567     45 2011-04-11             43.92       3.551  187.970363
# 421568     45 2011-04-11             43.92       3.551  187.970363
# 421569     45 2011-04-11             43.92       3.551  187.970363
#
#         Unemployment  IsHoliday  Dept  Weekly_Sales  Type    Size   MarkDown  \
# 0              7.866        0.0     1      18689.54   0.0  151315  25671.680
# ...

# %%
df1.head()
# Out:
#    Store       Date  Temperature_fahr  Fuel_Price         CPI  Unemployment  \
# 0      1 2011-11-11             59.11       3.297  217.998085         7.866
# 1      1 2011-11-11             59.11       3.297  217.998085         7.866
# 2      1 2011-11-11             59.11       3.297  217.998085         7.866
# 3      1 2011-11-11             59.11       3.297  217.998085         7.866
# 4      1 2011-11-11             59.11       3.297  217.998085         7.866
#
#    IsHoliday  Dept  Weekly_Sales  Type    Size  MarkDown  day  month  year  \
# 0        0.0     1      18689.54   0.0  151315  25671.68   11     11  2011
# 1        0.0     2      44936.47   0.0  151315  25671.68   11     11  2011
# 2        0.0     3       9959.64   0.0  151315  25671.68   11     11  2011
# 3        0.0     4      36826.52   0.0  151315  25671.68   11     11  2011
# 4        0.0     5      31002.65   0.0  151315  25671.68   11     11  2011
#
#    Month  weekly_sales_date  week_of_number
# ...

# %%
# df1.to_csv("ml_flow_data.csv",index=False)

# %% [markdown]
# # split train

# %%
x=df1.drop(['Date','Size','day','month','Month','Weekly_Sales','weekly_sales_date'],axis=1)
y=df1['Weekly_Sales']

# %%
x.head()
# Out:
#    Store  Temperature_fahr  Fuel_Price         CPI  Unemployment  IsHoliday  \
# 0      1             59.11       3.297  217.998085         7.866        0.0
# 1      1             59.11       3.297  217.998085         7.866        0.0
# 2      1             59.11       3.297  217.998085         7.866        0.0
# 3      1             59.11       3.297  217.998085         7.866        0.0
# 4      1             59.11       3.297  217.998085         7.866        0.0
#
#    Dept  Type  MarkDown  year  week_of_number
# 0     1   0.0  25671.68  2011              45
# 1     2   0.0  25671.68  2011              45
# 2     3   0.0  25671.68  2011              45
# 3     4   0.0  25671.68  2011              45
# 4     5   0.0  25671.68  2011              45

# %%
# min_Temperature = df['Temperature_fahr'].min()
# max_Temperature = df['Temperature_fahr'].max()
# min_Fuel_Price = df['Fuel_Price'].min()
# max_Fuel_Price = df['Fuel_Price'].max()
# min_CPI = df['CPI'].min()
# max_CPI = df['CPI'].max()
# min_Unemployment= df['Unemployment'].min()
# max_Unemployment = df['Unemployment'].max()
# min_weekly_sales_date = df['weekly_sales_date'].min()
# max_weekly_sales_date = df['weekly_sales_date'].max()
# min_MarkDown = df['MarkDown'].min()
# max_MarkDown = df['MarkDown'].max()

# Store = st.selectbox("**Select a Store Id**",options = df['Store'].unique())
# Temperature_fahr = st.number_input(f'**Enter Temperature_fahr (Minimum : {min_Temperature}, Maximun : {max_Temperature})**')
# Fuel_Price = st.number_input(f'**Enter Fuel_Price (Minimum : {min_Fuel_Price}, Maximun : {max_Fuel_Price})**')
# CPI = st.number_input(f'**Enter CPI (Minimum : {min_CPI}, Maximun : {max_CPI})**')
# Unemployment = st.number_input(f'**Enter Unemployment  (Minimum : {min_Unemployment}, Maximun : {max_Unemployment})**')
# IsHoliday = st.selectbox("**Select a IsHoliday Id**",options = df['IsHoliday'].unique())
# Dept = st.selectbox("**Select a Dept Id**",options = df['Dept'].unique())
# Type = st.selectbox("**Select a Type **",options = df['Type'].unique())
# MarkDown = st.number_input(f'**Enter MarkDown  (Minimum : {min_MarkDown}, Maximun : {max_MarkDown})**')
# year = st.number_input('**Enter the year')

# %%
y
# Out:
# 0         18689.54
# 1         44936.47
# 2          9959.64
# 3         36826.52
# 4         31002.65
#             ...
# 421565     1640.50
# 421566     3160.91
# 421567    53342.74
# 421568     6093.25
# 421569      749.18
# Name: Weekly_Sales, Length: 421570, dtype: float64

# %%
from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=23)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((337256, 11), (84314, 11), (337256,), (84314,))

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=90,random_state=15,max_depth=21,min_samples_split=10)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=21, min_samples_split=10, n_estimators=90,
#                       random_state=15)

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mean_squared_error(y_pred,y_test)
# Out:
# 22241664.344885413

# %%
mean_absolute_error(y_pred,y_test)
# Out:
# 1877.6026415640401

# %%
# n_estimators=90,random_state=15,max_depth=21,min_samples_split=10       1863
# n_estimators=85,random_state=15,max_depth=22,min_samples_split=5        1820

# %%
import pickle

# %%
with open('random_regression.pkl','wb') as file:
    pickle.dump(model,file)

# %%
with open('random_regression.pkl','rb') as file:
    Result = pickle.load(file)

# %%
y_pred=Result.predict(x_test)

# %%
mean_absolute_error(y_pred,y_test)
# Out:
# 1877.6026415640401

# %%
ddasata=np.array([[1,59.11,3.297,217.998085,7.866,0.0,2,0.0,25671.68,2011,4]])

# %%
y_pred=Result.predict(ddasata)
y_pred
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([45843.38785567])

# %% [markdown]
# # knn

# %%
from sklearn.neighbors import KNeighborsRegressor
kmodel= KNeighborsRegressor(n_neighbors=3)
kmodel.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
y_pred=kmodel.predict(x_test)

# %%
y_pred1=kmodelodelodel.x_trainict(x_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 y_pred1=kmodelodelodel.x_trainict(x_train)
#
# NameError: name 'kmodelodelodel' is not defined

# %%
mean_absolute_error(y_pred,y_test)

# %%
mean_absolute_error(y_pred1,y_trainainainainain)

# %%
# adda boost 
# gradian boost

# %% [markdown]
# # extra tree

# %%
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor(n_estimators=90,random_state=10)
model.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
mean_absolute_error(y_pred,y_test)

# %% [markdown]
# # bagging

# %%
from sklearn.ensemble import BaggingRegressor
model=BaggingRegressor(n_estimators=100, random_state=10)
model.fit(x_train, y_train)
y_pred=model.predict(x_test)

# %%
mean_absolute_error(y_pred,y_test)

# %%
from lazypredict.Supervised import LazyRegressor

# %%
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(x_train, x_test, y_train, y_test)
