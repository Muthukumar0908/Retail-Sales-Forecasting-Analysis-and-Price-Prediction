# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing required packages and uploading required files

# %%
df1=pd.read_csv(r"C:\Users\ADMIN\Videos\capstion_project\final_project\Features_data_set.csv")
df2=pd.read_csv(r"C:\Users\ADMIN\Videos\capstion_project\final_project\sales_data_set.csv")
df3=pd.read_csv(r"C:\Users\ADMIN\Videos\capstion_project\final_project\stores_data_set.csv")

# %%
df1.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
df2.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False

# %%
df3.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %% [markdown]
# # Merge three data set using inner function

# %%
first_join= pd.merge(df1, df2, on=['Store',"Date",'IsHoliday'], how='inner')

# %%
data=pd.merge(first_join,df3,on=['Store'],how="inner")

# %%
data
# Out:
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1  05/02/2010        42.31       2.572        NaN        NaN
# 1           1  05/02/2010        42.31       2.572        NaN        NaN
# 2           1  05/02/2010        42.31       2.572        NaN        NaN
# 3           1  05/02/2010        42.31       2.572        NaN        NaN
# 4           1  05/02/2010        42.31       2.572        NaN        NaN
# ...       ...         ...          ...         ...        ...        ...
# 421565     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421566     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421567     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421568     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421569     45  26/10/2012        58.85       3.882    4018.91      58.08
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 0             NaN        NaN        NaN  211.096358         8.106      False
# 1             NaN        NaN        NaN  211.096358         8.106      False
# 2             NaN        NaN        NaN  211.096358         8.106      False
# 3             NaN        NaN        NaN  211.096358         8.106      False
# 4             NaN        NaN        NaN  211.096358         8.106      False
# ...           ...        ...        ...         ...           ...        ...
# 421565      100.0     211.94     858.33  192.308899         8.667      False
# 421566      100.0     211.94     858.33  192.308899         8.667      False
# 421567      100.0     211.94     858.33  192.308899         8.667      False
# 421568      100.0     211.94     858.33  192.308899         8.667      False
# 421569      100.0     211.94     858.33  192.308899         8.667      False
#
#         Dept  Weekly_Sales Type    Size
# 0          1      24924.50    A  151315
# 1          2      50605.27    A  151315
# 2          3      13740.12    A  151315
# 3          4      39954.04    A  151315
# 4          5      32229.38    A  151315
# ...      ...           ...  ...     ...
# 421565    93       2487.80    B  118221
# 421566    94       5203.31    B  118221
# 421567    95      56017.47    B  118221
# 421568    97       6817.48    B  118221
# 421569    98       1076.80    B  118221
#
# [421570 rows x 16 columns]

# %% [markdown]
# # funal data set

# %%
data_1  = data.copy()

# %% [markdown]
# # EDA

# %% [markdown]
# # Calcuate null percentage

# %%
null_percentage=(data_1.isnull().mean()*100).round(2)

# %%
pd.DataFrame({
    'columns':null_percentage.index,
    'null_percentage':null_percentage.values
}).sort_values('null_percentage',ascending=False)
# Out:
#          columns  null_percentage
# 5      MarkDown2            73.61
# 7      MarkDown4            67.98
# 6      MarkDown3            67.48
# 4      MarkDown1            64.26
# 8      MarkDown5            64.08
# 0          Store             0.00
# 1           Date             0.00
# 2    Temperature             0.00
# 3     Fuel_Price             0.00
# 9            CPI             0.00
# 10  Unemployment             0.00
# 11     IsHoliday             0.00
# 12          Dept             0.00
# 13  Weekly_Sales             0.00
# 14          Type             0.00
# 15          Size             0.00

# %% [markdown]
# # Zero percentage

# %%
lis=[]
for i in data_1.columns:
    zero_percentage=((data_1[i]== 0).mean())
    lis.append((i,zero_percentage))
zero_percent=pd.DataFrame(lis,columns=('columns','zero_percentage')).sort_values('zero_percentage',ascending=False)
zero_percent
# Out:
#          columns  zero_percentage
# 11     IsHoliday         0.929642
# 5      MarkDown2         0.000491
# 13  Weekly_Sales         0.000173
# 6      MarkDown3         0.000159
# 0          Store         0.000000
# 1           Date         0.000000
# 2    Temperature         0.000000
# 3     Fuel_Price         0.000000
# 4      MarkDown1         0.000000
# 7      MarkDown4         0.000000
# 8      MarkDown5         0.000000
# 9            CPI         0.000000
# 10  Unemployment         0.000000
# 12          Dept         0.000000
# 14          Type         0.000000
# 15          Size         0.000000

# %%
data_1.fillna(0,inplace=True)

# %%
data_1
# Out:
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1  05/02/2010        42.31       2.572       0.00       0.00
# 1           1  05/02/2010        42.31       2.572       0.00       0.00
# 2           1  05/02/2010        42.31       2.572       0.00       0.00
# 3           1  05/02/2010        42.31       2.572       0.00       0.00
# 4           1  05/02/2010        42.31       2.572       0.00       0.00
# ...       ...         ...          ...         ...        ...        ...
# 421565     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421566     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421567     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421568     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421569     45  26/10/2012        58.85       3.882    4018.91      58.08
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 0             0.0       0.00       0.00  211.096358         8.106      False
# 1             0.0       0.00       0.00  211.096358         8.106      False
# 2             0.0       0.00       0.00  211.096358         8.106      False
# 3             0.0       0.00       0.00  211.096358         8.106      False
# 4             0.0       0.00       0.00  211.096358         8.106      False
# ...           ...        ...        ...         ...           ...        ...
# 421565      100.0     211.94     858.33  192.308899         8.667      False
# 421566      100.0     211.94     858.33  192.308899         8.667      False
# 421567      100.0     211.94     858.33  192.308899         8.667      False
# 421568      100.0     211.94     858.33  192.308899         8.667      False
# 421569      100.0     211.94     858.33  192.308899         8.667      False
#
#         Dept  Weekly_Sales Type    Size
# 0          1      24924.50    A  151315
# 1          2      50605.27    A  151315
# 2          3      13740.12    A  151315
# 3          4      39954.04    A  151315
# 4          5      32229.38    A  151315
# ...      ...           ...  ...     ...
# 421565    93       2487.80    B  118221
# 421566    94       5203.31    B  118221
# 421567    95      56017.47    B  118221
# 421568    97       6817.48    B  118221
# 421569    98       1076.80    B  118221
#
# [421570 rows x 16 columns]

# %% [markdown]
# # Total number of vector

# %%
data_1.shape[0]
# Out:
# 421570

# %% [markdown]
# # Total number of column

# %%
data_1.shape[1]
# Out:
# 16

# %% [markdown]
# # Data information

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Date          421570 non-null  object
#  2   Temperature   421570 non-null  float64
#  3   Fuel_Price    421570 non-null  float64
#  4   MarkDown1     150681 non-null  float64
#  5   MarkDown2     111248 non-null  float64
#  6   MarkDown3     137091 non-null  float64
#  7   MarkDown4     134967 non-null  float64
#  8   MarkDown5     151432 non-null  float64
#  9   CPI           421570 non-null  float64
#  10  Unemployment  421570 non-null  float64
#  11  IsHoliday     421570 non-null  bool
#  12  Dept          421570 non-null  int64
#  13  Weekly_Sales  421570 non-null  float64
#  14  Type          421570 non-null  object
#  15  Size          421570 non-null  int64
# dtypes: bool(1), float64(10), int64(3), object(2)
# memory usage: 51.9+ MB

# %% [markdown]
# # Merge all MarkDown

# %%
data_1['MarkDown']=data_1['MarkDown1']+data_1['MarkDown2']+data_1['MarkDown3']+data_1['MarkDown4']+data_1['MarkDown5']

# %%
data_1.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  05/02/2010        42.31       2.572        NaN        NaN
# 2      1  05/02/2010        42.31       2.572        NaN        NaN
# 3      1  05/02/2010        42.31       2.572        NaN        NaN
# 4      1  05/02/2010        42.31       2.572        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  Dept  \
# 0        NaN        NaN        NaN  211.096358         8.106      False     1
# 1        NaN        NaN        NaN  211.096358         8.106      False     2
# 2        NaN        NaN        NaN  211.096358         8.106      False     3
# 3        NaN        NaN        NaN  211.096358         8.106      False     4
# 4        NaN        NaN        NaN  211.096358         8.106      False     5
#
#    Weekly_Sales Type    Size  MarkDown
# 0      24924.50    A  151315       NaN
# 1      50605.27    A  151315       NaN
# 2      13740.12    A  151315       NaN
# 3      39954.04    A  151315       NaN
# 4      32229.38    A  151315       NaN

# %% [markdown]
# # Hide the all Markdown

# %%
data_2=data_1.drop(columns=['MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5'],axis=1)

# %% [markdown]
# # Final data

# %%
data_2
# Out:
#         Store        Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0           1  05/02/2010        42.31       2.572  211.096358         8.106
# 1           1  05/02/2010        42.31       2.572  211.096358         8.106
# 2           1  05/02/2010        42.31       2.572  211.096358         8.106
# 3           1  05/02/2010        42.31       2.572  211.096358         8.106
# 4           1  05/02/2010        42.31       2.572  211.096358         8.106
# ...       ...         ...          ...         ...         ...           ...
# 421565     45  26/10/2012        58.85       3.882  192.308899         8.667
# 421566     45  26/10/2012        58.85       3.882  192.308899         8.667
# 421567     45  26/10/2012        58.85       3.882  192.308899         8.667
# 421568     45  26/10/2012        58.85       3.882  192.308899         8.667
# 421569     45  26/10/2012        58.85       3.882  192.308899         8.667
#
#         IsHoliday  Dept  Weekly_Sales Type    Size  MarkDown
# 0           False     1      24924.50    A  151315       NaN
# 1           False     2      50605.27    A  151315       NaN
# 2           False     3      13740.12    A  151315       NaN
# 3           False     4      39954.04    A  151315       NaN
# 4           False     5      32229.38    A  151315       NaN
# ...           ...   ...           ...  ...     ...       ...
# 421565      False    93       2487.80    B  118221   5247.26
# 421566      False    94       5203.31    B  118221   5247.26
# 421567      False    95      56017.47    B  118221   5247.26
# 421568      False    97       6817.48    B  118221   5247.26
# 421569      False    98       1076.80    B  118221   5247.26
#
# [421570 rows x 12 columns]

# %%
data_2[data_2['MarkDown']==0]
# Out:
# Empty DataFrame
# Columns: [Store, Date, Temperature, Fuel_Price, CPI, Unemployment, IsHoliday, Dept, Weekly_Sales, Type, Size, MarkDown]
# Index: []

# %%
data_2['MarkDown'].replace(0, np.nan, inplace=True)

# %%
data_2
# Out:
#         Store        Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0           1  05/02/2010        42.31       2.572  211.096358         8.106
# 1           1  05/02/2010        42.31       2.572  211.096358         8.106
# 2           1  05/02/2010        42.31       2.572  211.096358         8.106
# 3           1  05/02/2010        42.31       2.572  211.096358         8.106
# 4           1  05/02/2010        42.31       2.572  211.096358         8.106
# ...       ...         ...          ...         ...         ...           ...
# 421565     45  26/10/2012        58.85       3.882  192.308899         8.667
# 421566     45  26/10/2012        58.85       3.882  192.308899         8.667
# 421567     45  26/10/2012        58.85       3.882  192.308899         8.667
# 421568     45  26/10/2012        58.85       3.882  192.308899         8.667
# 421569     45  26/10/2012        58.85       3.882  192.308899         8.667
#
#         IsHoliday  Dept  Weekly_Sales Type    Size  MarkDown
# 0           False     1      24924.50    A  151315       NaN
# 1           False     2      50605.27    A  151315       NaN
# 2           False     3      13740.12    A  151315       NaN
# 3           False     4      39954.04    A  151315       NaN
# 4           False     5      32229.38    A  151315       NaN
# ...           ...   ...           ...  ...     ...       ...
# 421565      False    93       2487.80    B  118221   5247.26
# 421566      False    94       5203.31    B  118221   5247.26
# 421567      False    95      56017.47    B  118221   5247.26
# 421568      False    97       6817.48    B  118221   5247.26
# 421569      False    98       1076.80    B  118221   5247.26
#
# [421570 rows x 12 columns]

# %% [markdown]
# # Calculate the all null values

# %%
data_2.isnull().sum()
# Out:
# Store                0
# Date                 0
# Temperature          0
# Fuel_Price           0
# CPI                  0
# Unemployment         0
# IsHoliday            0
# Dept                 0
# Weekly_Sales         0
# Type                 0
# Size                 0
# MarkDown        324514
# dtype: int64

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421570 entries, 0 to 421569
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Date          421570 non-null  object
#  2   Temperature   421570 non-null  float64
#  3   Fuel_Price    421570 non-null  float64
#  4   CPI           421570 non-null  float64
#  5   Unemployment  421570 non-null  float64
#  6   IsHoliday     421570 non-null  bool
#  7   Dept          421570 non-null  int64
#  8   Weekly_Sales  421570 non-null  float64
#  9   Type          421570 non-null  object
#  10  Size          421570 non-null  int64
#  11  MarkDown      97056 non-null   float64
# dtypes: bool(1), float64(6), int64(3), object(2)
# memory usage: 55.1+ MB

# %% [markdown]
# # calculate  the dublicate value

# %%
dublicate=data_2.duplicated().sum()

# %%
print("total dublicate count:",dublicate)
# Out:
# total dublicate count: 0

# %% [markdown]
# # Check the data distribution

# %% [markdown]
# ## plot show

# %%
for i in data_2.columns:
    if data_2[i].dtype != 'object':
        print(i)
        plt.figure(figsize=(16,6))
        sns.boxplot(data=data_2[i])
        plt.show()
# Out:
# Store
# Temperature
# Fuel_Price
# CPI
# Unemployment
# IsHoliday
# Dept
# Weekly_Sales
# Size
# MarkDown

# %% [markdown]
# ## single image of data  outlier

# %%
plt.figure(figsize=(16,6))
sns.boxplot(data=data_2)
plt.show()

# %%
for i in data_2.columns:
    if data_2[i].dtype != "object":
        print(i)
        sns.distplot(data_2[i],color="g")
        plt.show()
# Out:
# Store
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\3550191943.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2[i],color="g")
# Temperature
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\3550191943.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2[i],color="g")
# Fuel_Price
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\3550191943.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2[i],color="g")
# CPI
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\3550191943.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2[i],color="g")
# Unemployment
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\3550191943.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2[i],color="g")
# IsHoliday
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\3550191943.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2[i],color="g")
# Dept
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\3550191943.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2[i],color="g")
# Weekly_Sales
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\3550191943.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2[i],color="g")
# Size
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\3550191943.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2[i],color="g")
# MarkDown
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\3550191943.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2[i],color="g")

# %% [markdown]
# # Fill the null values in related to other column s values

# %%
# data_2[data_2['Weekly_Sales']==0]

# %%
mean=(data_2[(data_2['Store']==1)&(data_2['Type']=="A")&(data_2['IsHoliday']==False)&(data_2['Dept']==47)]['Weekly_Sales'].mean()).round(2)

# %%
mean
# Out:
# -116.45

# %%
k=data_2[data_2['Weekly_Sales']==0]

# %% [markdown]
# # 73 null values vector(row) in weekly sales

# %%
k
# Out:
#         Store        Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 4132        1  11/03/2011        53.56       3.459  214.111056         7.742
# 5691        1  12/08/2011        90.76       3.638  215.605788         7.962
# 5762        1  19/08/2011        89.94       3.554  215.669311         7.962
# 10732       2  19/03/2010        54.52       2.720  210.873332         8.324
# 18449       2  13/04/2012        68.08       3.891  221.148403         6.891
# ...       ...         ...          ...         ...         ...           ...
# 402827     43  13/01/2012        43.68       3.261  211.411571         9.653
# 407180     44  14/01/2011        20.60       2.903  127.300935         7.224
# 414388     45  15/10/2010        58.61       2.868  182.810620         8.724
# 415525     45  11/02/2011        30.30       3.239  183.701613         8.549
# 421007     45  31/08/2012        75.09       3.867  191.461281         8.684
#
#         IsHoliday  Dept  Weekly_Sales Type    Size  MarkDown
# 4132        False    47           0.0    A  151315       NaN
# 5691        False    47           0.0    A  151315       NaN
# 5762        False    47           0.0    A  151315       NaN
# 10732       False    60           0.0    A  202307       NaN
# 18449       False    47           0.0    A  202307  21715.91
# ...           ...   ...           ...  ...     ...       ...
# 402827      False    85           0.0    C   41062       NaN
# 407180      False    27           0.0    C   39910       NaN
# 414388      False    54           0.0    B  118221       NaN
# 415525       True    47           0.0    B  118221       NaN
# 421007      False    54           0.0    B  118221  34720.67
#
# [73 rows x 12 columns]

# %% [markdown]
# # Replace related values in related data

# %%
for i,j,d,e in zip(k['Store'], k['Type'],k['IsHoliday'],k['Dept']):
    print(i,j,d,e)
    mean=data_2[(data_2['Store']==i)&(data_2['Type']==j)&(data_2['IsHoliday']==d)&(data_2['Dept']==e)]['Weekly_Sales'].mean()
    data_2.loc[(data_2['Store']==i)&(data_2['Type']==j)&(data_2['IsHoliday']==d)&(data_2['Dept']==e), 'Weekly_Sales']= mean
# Out:
# 1 A False 47
# 1 A False 47
# 1 A False 47
# 2 A False 60
# 2 A False 47
# 3 B False 36
# 6 A False 78
# 7 B False 54
# 7 B False 49
# 8 A False 78
# 9 B False 54
# 10 B False 47
# 10 B False 78
# 10 B False 47
# 10 B False 78
# 10 B False 47
# 11 A False 19
# 12 B False 54
# 12 B False 47
# 12 B False 54
# 13 A False 45
# 13 A False 78
# 14 A False 47
# 14 A False 51
# 14 A False 78
# 15 B True 51
# 15 B False 54
# 16 B False 47
# 16 B False 48
# 17 B False 49
# 17 B False 41
# 17 B True 77
# 18 B False 78
# 18 B False 47
# 19 A False 51
# 19 A False 54
# 19 A False 78
# 19 A False 54
# 19 A False 47
# 20 A False 19
# 20 A False 47
# 20 A False 48
# 21 B False 98
# 21 B False 98
# 22 B False 48
# 25 B False 54
# 25 B False 51
# 25 B False 54
# 26 A False 60
# 26 A False 47
# 27 A False 47
# 27 A False 47
# 28 A False 47
# 30 C False 56
# 31 A False 18
# 31 A False 54
# 32 A False 78
# 33 A False 25
# 35 B False 47
# 35 B False 54
# 38 C False 44
# 38 C False 20
# 39 A False 60
# 41 A False 78
# 42 C False 27
# 42 C False 44
# 43 C False 32
# 43 C False 32
# 43 C False 85
# 44 C False 27
# 45 B False 54
# 45 B True 47
# 45 B False 54

# %%
data_2[data_2['Weekly_Sales']==0]
# Out:
# Empty DataFrame
# Columns: [Store, Date, Temperature, Fuel_Price, CPI, Unemployment, IsHoliday, Dept, Weekly_Sales, Type, Size, MarkDown]
# Index: []

# %% [markdown]
# # apply in inverse transform in weekly_sales

# %% [markdown]
# ### I will predict the markdown values using the weekly sales data.

# %%
def inverse(x):
    return 1/x

# %%
data_4=data_2.copy()
data_4['Weekly_Sales']=data_4['Weekly_Sales'].apply(inverse)

# %%
# data_4=data_2.copy()

# %%
data_4
# Out:
#         Store        Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0           1  05/02/2010        42.31       2.572  211.096358         8.106
# 1           1  05/02/2010        42.31       2.572  211.096358         8.106
# 2           1  05/02/2010        42.31       2.572  211.096358         8.106
# 3           1  05/02/2010        42.31       2.572  211.096358         8.106
# 4           1  05/02/2010        42.31       2.572  211.096358         8.106
# ...       ...         ...          ...         ...         ...           ...
# 421565     45  26/10/2012        58.85       3.882  192.308899         8.667
# 421566     45  26/10/2012        58.85       3.882  192.308899         8.667
# 421567     45  26/10/2012        58.85       3.882  192.308899         8.667
# 421568     45  26/10/2012        58.85       3.882  192.308899         8.667
# 421569     45  26/10/2012        58.85       3.882  192.308899         8.667
#
#         IsHoliday  Dept  Weekly_Sales Type    Size  MarkDown
# 0           False     1      0.000040    A  151315       NaN
# 1           False     2      0.000020    A  151315       NaN
# 2           False     3      0.000073    A  151315       NaN
# 3           False     4      0.000025    A  151315       NaN
# 4           False     5      0.000031    A  151315       NaN
# ...           ...   ...           ...  ...     ...       ...
# 421565      False    93      0.000402    B  118221   5247.26
# 421566      False    94      0.000192    B  118221   5247.26
# 421567      False    95      0.000018    B  118221   5247.26
# 421568      False    97      0.000147    B  118221   5247.26
# 421569      False    98      0.000929    B  118221   5247.26
#
# [421570 rows x 12 columns]

# %% [markdown]
# # See the Markdown values outlier

# %%
plt.figure(figsize=(16,6))
sns.boxplot(data=data_4)
plt.show()

# %% [markdown]
# ### dont apply inverse transformation

# %% [markdown]
# #### see all outliers

# %%
data_3=data_2.copy()

# %%
plt.figure(figsize=(16,6))
sns.boxplot(data=data_3)
plt.show()

# %%
for i in data_3.columns:
    if data_3[i].dtype != "object":
        print(i)
        sns.distplot(data_3[i],color="g")
        plt.show()
# Out:
# Store
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\2424780918.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3[i],color="g")
# Temperature
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\2424780918.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3[i],color="g")
# Fuel_Price
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\2424780918.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3[i],color="g")
# CPI
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\2424780918.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3[i],color="g")
# Unemployment
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\2424780918.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3[i],color="g")
# IsHoliday
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\2424780918.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3[i],color="g")
# Dept
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\2424780918.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3[i],color="g")
# Weekly_Sales
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\2424780918.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3[i],color="g")
# Size
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\2424780918.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3[i],color="g")
# MarkDown
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\2424780918.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3[i],color="g")

# %%
data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421570 entries, 0 to 421569
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Date          421570 non-null  object
#  2   Temperature   421570 non-null  float64
#  3   Fuel_Price    421570 non-null  float64
#  4   CPI           421570 non-null  float64
#  5   Unemployment  421570 non-null  float64
#  6   IsHoliday     421570 non-null  bool
#  7   Dept          421570 non-null  int64
#  8   Weekly_Sales  421570 non-null  float64
#  9   Type          421570 non-null  object
#  10  Size          421570 non-null  int64
#  11  MarkDown      97056 non-null   float64
# dtypes: bool(1), float64(6), int64(3), object(2)
# memory usage: 55.1+ MB

# %%
data_3['Date']=pd.to_datetime(data_3['Date'])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\1375922476.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data_3['Date']=pd.to_datetime(data_3['Date'])

# %%
data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421570 entries, 0 to 421569
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Date          421570 non-null  datetime64[ns]
#  2   Temperature   421570 non-null  float64
#  3   Fuel_Price    421570 non-null  float64
#  4   CPI           421570 non-null  float64
#  5   Unemployment  421570 non-null  float64
#  6   IsHoliday     421570 non-null  bool
#  7   Dept          421570 non-null  int64
#  8   Weekly_Sales  421570 non-null  float64
#  9   Type          421570 non-null  object
#  10  Size          421570 non-null  int64
#  11  MarkDown      151432 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(6), int64(3), object(1)
# memory usage: 55.1+ MB

# %% [markdown]
# ### just try for markdown values predict in ml

# %% [markdown]
# #  ordinalEncoding

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()
for i in data_3.columns:
    if data_3[i].dtype == 'object' and data_3[i].dtype =='bool':
#         col_name = i
        data_3[i] = enc.fit_transform(data_3[[i]])
        encoding = data_3[i].sort_values().unique()
        globals()[i] = {}
        decoded_data = enc.inverse_transform(data_3[[i]])
        decoded = sorted(np.unique(decoded_data)) 
        globals()[i] = dict(zip(decoded, encoding))

# %%
enc=OrdinalEncoder()
data_3["Type"] = enc.fit_transform(data_3[["Type"]])

# %%
data_3.Type.value_counts()
# Out:
# 0.0    215478
# 1.0    163495
# 2.0     42597
# Name: Type, dtype: int64

# %%
data_3.IsHoliday.value_counts()
# Out:
# 0.0    391909
# 1.0     29661
# Name: IsHoliday, dtype: int64

# %%
enc=OrdinalEncoder()
data_3["IsHoliday"] = enc.fit_transform(data_3[["IsHoliday"]])

# %%
data_3['IsHoliday'].value_counts()
# Out:
# 0.0    391909
# 1.0     29661
# Name: IsHoliday, dtype: int64

# %% [markdown]
# # Markdown value prediction

# %%
data_3.head()
# Out:
#    Store       Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0      1 2010-05-02        42.31       2.572  211.096358         8.106
# 1      1 2010-05-02        42.31       2.572  211.096358         8.106
# 2      1 2010-05-02        42.31       2.572  211.096358         8.106
# 3      1 2010-05-02        42.31       2.572  211.096358         8.106
# 4      1 2010-05-02        42.31       2.572  211.096358         8.106
#
#    IsHoliday  Dept  Weekly_Sales  Type    Size  MarkDown
# 0        0.0     1      24924.50   0.0  151315       NaN
# 1        0.0     2      50605.27   0.0  151315       NaN
# 2        0.0     3      13740.12   0.0  151315       NaN
# 3        0.0     4      39954.04   0.0  151315       NaN
# 4        0.0     5      32229.38   0.0  151315       NaN

# %%
data_3['weekly_sales_weeks']=data_3['Date'].dt.weekofyear
data_3['year']=data_3['Date'].dt.year
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\4018087573.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   data_3['weekly_sales_weeks']=data_3['Date'].dt.weekofyear

# %% [markdown]
# # split nan value in Markdown

# %%
null_values=data_3[data_3['MarkDown'].isnull()]

# %%
not_null_values=data_3[data_3['MarkDown'].isnull()== False]

# %%
not_null_values
# Out:
#         Store       Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 6587        1 2011-11-11        59.11       3.297  217.998085         7.866
# 6588        1 2011-11-11        59.11       3.297  217.998085         7.866
# 6589        1 2011-11-11        59.11       3.297  217.998085         7.866
# 6590        1 2011-11-11        59.11       3.297  217.998085         7.866
# 6591        1 2011-11-11        59.11       3.297  217.998085         7.866
# ...       ...        ...          ...         ...         ...           ...
# 421565     45 2012-10-26        58.85       3.882  192.308899         8.667
# 421566     45 2012-10-26        58.85       3.882  192.308899         8.667
# 421567     45 2012-10-26        58.85       3.882  192.308899         8.667
# 421568     45 2012-10-26        58.85       3.882  192.308899         8.667
# 421569     45 2012-10-26        58.85       3.882  192.308899         8.667
#
#         IsHoliday  Dept  Weekly_Sales  Type    Size  MarkDown  \
# 6587          0.0     1      18689.54   0.0  151315  25671.68
# 6588          0.0     2      44936.47   0.0  151315  25671.68
# 6589          0.0     3       9959.64   0.0  151315  25671.68
# 6590          0.0     4      36826.52   0.0  151315  25671.68
# 6591          0.0     5      31002.65   0.0  151315  25671.68
# ...           ...   ...           ...   ...     ...       ...
# 421565        0.0    93       2487.80   1.0  118221   5247.26
# 421566        0.0    94       5203.31   1.0  118221   5247.26
# 421567        0.0    95      56017.47   1.0  118221   5247.26
# 421568        0.0    97       6817.48   1.0  118221   5247.26
# 421569        0.0    98       1076.80   1.0  118221   5247.26
#
#         weekly_sales_weeks  year
# 6587                    45  2011
# 6588                    45  2011
# 6589                    45  2011
# 6590                    45  2011
# 6591                    45  2011
# ...                    ...   ...
# 421565                  43  2012
# 421566                  43  2012
# 421567                  43  2012
# 421568                  43  2012
# 421569                  43  2012
#
# [97056 rows x 14 columns]

# %%
x=not_null_values.drop(columns=['Date','MarkDown','Size'],axis=1)
y=not_null_values['MarkDown']

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %% [markdown]
# ## fill the null values in markdown

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=90,random_state=15,max_depth=22,min_samples_split=25)
model.fit(x,y)
# Out:
# RandomForestRegressor(max_depth=22, min_samples_split=25, n_estimators=90,
#                       random_state=15)

# %%
# from sklearn.neighbors import KNeighborsRegressor
# model= KNeighborsRegressor(n_neighbors=2)
# model.fit(x,y)

# %%
y_pred=model.predict(x)

# %%
y_pred
# Out:
# array([25671.68, 25671.68, 25671.68, ...,  5247.26,  5247.26,  5247.26])

# %%
mean_absolute_error(y_pred,y)
# Out:
# 20.428043040415762

# %% [markdown]
# # null value prediction

# %%
x1=null_values.drop(columns=['Date','MarkDown','Size'],axis=1)

# %%
null_predict=model.predict(x1)

# %%
null_predict
# Out:
# array([45502.34122222, 45502.34122222, 45502.34122222, ...,
#         6096.19244444,  6096.19244444,  6096.19244444])

# %% [markdown]
# # insert null value in data set

# %%
null_values['MarkDown']= null_predict
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\2140423591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_values['MarkDown']= null_predict

# %%
null_values
# Out:
#         Store       Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0           1 2010-05-02        42.31       2.572  211.096358         8.106
# 1           1 2010-05-02        42.31       2.572  211.096358         8.106
# 2           1 2010-05-02        42.31       2.572  211.096358         8.106
# 3           1 2010-05-02        42.31       2.572  211.096358         8.106
# 4           1 2010-05-02        42.31       2.572  211.096358         8.106
# ...       ...        ...          ...         ...         ...           ...
# 421498     45 2012-10-19        56.47       3.969  192.330854         8.667
# 421499     45 2012-10-19        56.47       3.969  192.330854         8.667
# 421500     45 2012-10-19        56.47       3.969  192.330854         8.667
# 421501     45 2012-10-19        56.47       3.969  192.330854         8.667
# 421502     45 2012-10-19        56.47       3.969  192.330854         8.667
#
#         IsHoliday  Dept  Weekly_Sales  Type    Size      MarkDown  \
# 0             0.0     1      24924.50   0.0  151315  45502.341222
# 1             0.0     2      50605.27   0.0  151315  45502.341222
# 2             0.0     3      13740.12   0.0  151315  45502.341222
# 3             0.0     4      39954.04   0.0  151315  45502.341222
# 4             0.0     5      32229.38   0.0  151315  45502.341222
# ...           ...   ...           ...   ...     ...           ...
# 421498        0.0    93       2270.50   1.0  118221   6096.192444
# 421499        0.0    94       4655.65   1.0  118221   6096.192444
# 421500        0.0    95      48434.97   1.0  118221   6096.192444
# 421501        0.0    97       5575.90   1.0  118221   6096.192444
# 421502        0.0    98        760.01   1.0  118221   6096.192444
#
#         weekly_sales_weeks  year
# 0                       17  2010
# 1                       17  2010
# 2                       17  2010
# 3                       17  2010
# 4                       17  2010
# ...                    ...   ...
# 421498                  42  2012
# 421499                  42  2012
# 421500                  42  2012
# 421501                  42  2012
# 421502                  42  2012
#
# [324514 rows x 14 columns]

# %% [markdown]
# # merge null value data set and not null value data set

# %%
clean_data=pd.concat([null_values,not_null_values],ignore_index=True)
clean_data.shape
# Out:
# (421570, 14)

# %%
151432+270138
# Out:
# 421570

# %%
clean_data
# Out:
#         Store       Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0           1 2010-05-02        42.31       2.572  211.096358         8.106
# 1           1 2010-05-02        42.31       2.572  211.096358         8.106
# 2           1 2010-05-02        42.31       2.572  211.096358         8.106
# 3           1 2010-05-02        42.31       2.572  211.096358         8.106
# 4           1 2010-05-02        42.31       2.572  211.096358         8.106
# ...       ...        ...          ...         ...         ...           ...
# 421565     45 2012-10-26        58.85       3.882  192.308899         8.667
# 421566     45 2012-10-26        58.85       3.882  192.308899         8.667
# 421567     45 2012-10-26        58.85       3.882  192.308899         8.667
# 421568     45 2012-10-26        58.85       3.882  192.308899         8.667
# 421569     45 2012-10-26        58.85       3.882  192.308899         8.667
#
#         IsHoliday  Dept  Weekly_Sales  Type    Size      MarkDown  \
# 0             0.0     1      24924.50   0.0  151315  45502.341222
# 1             0.0     2      50605.27   0.0  151315  45502.341222
# 2             0.0     3      13740.12   0.0  151315  45502.341222
# 3             0.0     4      39954.04   0.0  151315  45502.341222
# 4             0.0     5      32229.38   0.0  151315  45502.341222
# ...           ...   ...           ...   ...     ...           ...
# 421565        0.0    93       2487.80   1.0  118221   5247.260000
# 421566        0.0    94       5203.31   1.0  118221   5247.260000
# 421567        0.0    95      56017.47   1.0  118221   5247.260000
# 421568        0.0    97       6817.48   1.0  118221   5247.260000
# 421569        0.0    98       1076.80   1.0  118221   5247.260000
#
#         weekly_sales_weeks  year
# 0                       17  2010
# 1                       17  2010
# 2                       17  2010
# 3                       17  2010
# 4                       17  2010
# ...                    ...   ...
# 421565                  43  2012
# 421566                  43  2012
# 421567                  43  2012
# 421568                  43  2012
# 421569                  43  2012
#
# [421570 rows x 14 columns]

# %%
# pd.set_option('display.max_rows', None)

# %%
clean_data.head(50000)
# Out:
#        Store       Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0          1 2010-05-02        42.31       2.572  211.096358         8.106
# 1          1 2010-05-02        42.31       2.572  211.096358         8.106
# 2          1 2010-05-02        42.31       2.572  211.096358         8.106
# 3          1 2010-05-02        42.31       2.572  211.096358         8.106
# 4          1 2010-05-02        42.31       2.572  211.096358         8.106
# ...      ...        ...          ...         ...         ...           ...
# 49995      7 2012-06-04        44.29       3.854  197.597128         8.090
# 49996      7 2012-04-27        51.49       3.927  197.664546         8.090
# 49997      7 2012-04-27        51.49       3.927  197.664546         8.090
# 49998      7 2012-04-27        51.49       3.927  197.664546         8.090
# 49999      7 2012-04-27        51.49       3.927  197.664546         8.090
#
#        IsHoliday  Dept  Weekly_Sales  Type    Size      MarkDown  \
# 0            0.0     1      24924.50   0.0  151315  45502.341222
# 1            0.0     2      50605.27   0.0  151315  45502.341222
# 2            0.0     3      13740.12   0.0  151315  45502.341222
# 3            0.0     4      39954.04   0.0  151315  45502.341222
# 4            0.0     5      32229.38   0.0  151315  45502.341222
# ...          ...   ...           ...   ...     ...           ...
# 49995        0.0    98        376.88   1.0   70713   8282.712000
# 49996        0.0     1       6540.72   1.0   70713   8418.038000
# 49997        0.0     2      19383.49   1.0   70713   8418.038000
# 49998        0.0     3       6352.72   1.0   70713   8418.038000
# 49999        0.0     4      11889.64   1.0   70713   8418.038000
#
#        weekly_sales_weeks  year
# 0                      17  2010
# 1                      17  2010
# 2                      17  2010
# 3                      17  2010
# 4                      17  2010
# ...                   ...   ...
# 49995                  23  2012
# 49996                  17  2012
# 49997                  17  2012
# 49998                  17  2012
# 49999                  17  2012
#
# [50000 rows x 14 columns]

# %%
clean_data.to_csv('clean_dataset.csv',index=False)

# %%
data_2.head(500)
# Out:
#      Store        Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0        1  05/02/2010        42.31       2.572  211.096358         8.106
# 1        1  05/02/2010        42.31       2.572  211.096358         8.106
# 2        1  05/02/2010        42.31       2.572  211.096358         8.106
# 3        1  05/02/2010        42.31       2.572  211.096358         8.106
# 4        1  05/02/2010        42.31       2.572  211.096358         8.106
# ..     ...         ...          ...         ...         ...           ...
# 495      1  19/03/2010        54.58       2.720  211.215635         8.106
# 496      1  19/03/2010        54.58       2.720  211.215635         8.106
# 497      1  19/03/2010        54.58       2.720  211.215635         8.106
# 498      1  19/03/2010        54.58       2.720  211.215635         8.106
# 499      1  19/03/2010        54.58       2.720  211.215635         8.106
#
#      IsHoliday  Dept  Weekly_Sales Type    Size  MarkDown
# 0        False     1      24924.50    A  151315       NaN
# 1        False     2      50605.27    A  151315       NaN
# 2        False     3      13740.12    A  151315       NaN
# 3        False     4      39954.04    A  151315       NaN
# 4        False     5      32229.38    A  151315       NaN
# ..         ...   ...           ...  ...     ...       ...
# 495      False    81      30287.91    A  151315       NaN
# 496      False    82      18348.98    A  151315       NaN
# 497      False    83       6226.01    A  151315       NaN
# 498      False    85       4072.67    A  151315       NaN
# 499      False    87      28002.01    A  151315       NaN
#
# [500 rows x 12 columns]

# %%
data_2.isnull().sum()
# Out:
# Store                0
# Date                 0
# Temperature          0
# Fuel_Price           0
# CPI                  0
# Unemployment         0
# IsHoliday            0
# Dept                 0
# Weekly_Sales         0
# Type                 0
# Size                 0
# MarkDown        324514
# dtype: int64

# %%
data_2_null_value=data_2[data_2['MarkDown'].isnull()]

# %%
data_2_not_null_value=data_2[data_2['MarkDown'].isnull()==False]

# %%
data_2_null_value['MarkDown']= null_predict
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10136\1353573537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2_null_value['MarkDown']= null_predict

# %%
clean_analysis_data=pd.concat([data_2_not_null_value,data_2_null_value],ignore_index=True)
clean_analysis_data.shape
# Out:
# (421570, 12)

# %%
clean_analysis_data.to_csv('clean_analysis_data.csv',index=False)

# %% [markdown]
# ## open testing file
